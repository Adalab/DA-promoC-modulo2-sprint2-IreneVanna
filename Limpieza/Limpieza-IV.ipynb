# %% [markdown]
# # Pair Programming Limpieza IV

# %%
import pandas as pd
pd.options.display.max_columns = None
import sidetable
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("../datos/datos_limpiezaIII.csv")
df.head()
# Out:
#      year    country age           species         date month fatal sex  \
# 0  2018.0        usa  57       White shark  25-Jun-2018   Jun     n   F
# 1  2018.0     brazil  18       Tiger shark  03-Jun-2018   Jun     y   M
# 2  2018.0        usa  15    Bull shark, 6'  26-May-2018   May     n   M
# 3  2018.0  australia  32   Grey reef shark  24-May-2018   May     n   M
# 4  2018.0    england  21  Invalid incident  13-May-2018   May     n   M
#
#   main_species  age_numbers
# 0  white_shark         57.0
# 1  tiger_shark         18.0
# 2   bull_shark         15.0
# 3   grey_shark         32.0
# 4  unspecified         21.0

# %% [markdown]
# 1. Lo primero que tenemos que evaluar es en que columnas tenemos nulos y que cantidad tenemos en cada una. ¿Hay alguna columna con una gran cantidad de nulos? En caso de que sea así deberemos eliminarla.

# %%
df.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_50258">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50258_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_50258_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_50258_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50258_level0_row0" class="row_heading level0 row0" >age_numbers</th>
#       <td id="T_50258_row0_col0" class="data row0 col0" >152</td>
#       <td id="T_50258_row0_col1" class="data row0 col1" >1,666</td>
#       <td id="T_50258_row0_col2" class="data row0 col2" >9.12%</td>
#     </tr>
#     <tr>
#       <th id="T_50258_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_50258_row1_col0" class="data row1 col0" >148</td>
#       <td id="T_50258_row1_col1" class="data row1 col1" >1,666</td>
# ...

# %% [markdown]
# 2. Es el momento de eliminar los nulos:
# - Reemplazad los valores nulos de la columna age por la media de la edad, redondeada a dos decimales.
# - En relación a la columna de country al tratarse de una columna de tipo categórica, reemplazad los valores nulos por una nueva categória que se llame Unknown.
# - Reemplazad los valores nulos de la columna fatal por Unknown.
# - Reemplazad los valores nulos de la columna type por el valor más frecuente (la moda).
# - Reemplazad los valores nulos de la columna fecha por Unknown.
#
# Las columnas type y fecha ya las hemos eliminadas al principio del curso.

# %% [markdown]
# 2.  1 Reemplazad los valores nulos de la columna age por la media de la edad, redondeada a dos decimales.

# %%
df['age_numbers'].fillna(df['age_numbers'].mean ,inplace = True)

# %%
#Ya no hay nulos en la columna age_numbers
df.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af39f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af39f_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_af39f_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_af39f_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af39f_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_af39f_row0_col0" class="data row0 col0" >148</td>
#       <td id="T_af39f_row0_col1" class="data row0 col1" >1,666</td>
#       <td id="T_af39f_row0_col2" class="data row0 col2" >8.88%</td>
#     </tr>
#     <tr>
#       <th id="T_af39f_level0_row1" class="row_heading level0 row1" >species</th>
#       <td id="T_af39f_row1_col0" class="data row1 col0" >121</td>
#       <td id="T_af39f_row1_col1" class="data row1 col1" >1,666</td>
# ...

# %% [markdown]
# 2.2 En relación a la columna de country al tratarse de una columna de tipo categórica, reemplazad los valores nulos por una nueva categória que se llame Unknown.
#
# 2.3 Reemplazad los valores nulos de la columna fatal por Unknown.

# %%
df["country"].replace(np.nan, "unknow", inplace = True)
df["fatal"].replace(np.nan, "unknow", inplace = True)

# %%
#Ya no hay nulos en las columnas country y fatal
#Tener en cuenta que las columnas age y species son las antiguas por eso aparecen los nulos
df.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3722">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3722_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_a3722_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_a3722_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3722_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_a3722_row0_col0" class="data row0 col0" >148</td>
#       <td id="T_a3722_row0_col1" class="data row0 col1" >1,666</td>
#       <td id="T_a3722_row0_col2" class="data row0 col2" >8.88%</td>
#     </tr>
#     <tr>
#       <th id="T_a3722_level0_row1" class="row_heading level0 row1" >species</th>
#       <td id="T_a3722_row1_col0" class="data row1 col0" >121</td>
#       <td id="T_a3722_row1_col1" class="data row1 col1" >1,666</td>
# ...

# %%
df.head()
# Out:
#      year    country age           species         date month fatal sex  \
# 0  2018.0        usa  57       White shark  25-Jun-2018   Jun     n   F
# 1  2018.0     brazil  18       Tiger shark  03-Jun-2018   Jun     y   M
# 2  2018.0        usa  15    Bull shark, 6'  26-May-2018   May     n   M
# 3  2018.0  australia  32   Grey reef shark  24-May-2018   May     n   M
# 4  2018.0    england  21  Invalid incident  13-May-2018   May     n   M
#
#   main_species age_numbers
# 0  white_shark        57.0
# 1  tiger_shark        18.0
# 2   bull_shark        15.0
# 3   grey_shark        32.0
# 4  unspecified        21.0

# %%
df.to_csv("../datos/datos_limpiezaIV.csv")
